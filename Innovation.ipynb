# %% [markdown]
# **Run the cells to enhance the image generated by BachGAN. We have used the code given by Residual Dense Network for Image Super-Resolution (Zhang et al. 2018) which was available on Github. This notebook has been coded to run on Google Colab. For running this on some different platform, the source of the file given in the code should be changed accordingly.**

# %%
! git clone https://github.com/quasayush/image-super-resolution.git
# Out:
# fatal: destination path 'image-super-resolution' already exists and is not an empty directory.

# %%
! pip install ISR
# Out:
# ...
#      |████████████████████████████████| 86.3MB 37kB/s
# ...
#      |████████████████████████████████| 3.8MB 73.0MB/s
# ...
#      |████████████████████████████████| 450kB 60.8MB/s
# ...
#      |████████████████████████████████| 51kB 7.3MB/s
# ...
#   Created wheel for gast: filename=gast-0.2.2-cp36-none-any.whl size=7542 sha256=1a0e20072eda596a8fcdeb9723d37bfad959fd3c49443ac36c3c59f58af504ce
#   Stored in directory: /root/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd
# Successfully built gast
# ERROR: tensorflow-probability 0.11.0 has requirement gast>=0.3.2, but you'll have gast 0.2.2 which is incompatible.
# ...
#   Found existing installation: tensorboard 2.3.0
#     Uninstalling tensorboard-2.3.0:
#       Successfully uninstalled tensorboard-2.3.0
#   Found existing installation: tensorflow-estimator 2.3.0
#     Uninstalling tensorflow-estimator-2.3.0:
#       Successfully uninstalled tensorflow-estimator-2.3.0
#   Found existing installation: gast 0.3.3
# ...

# %%
! python /content/image-super-resolution/setup.py install
# Out:
# running install
# running bdist_egg
# running egg_info
# creating ISR.egg-info
# writing ISR.egg-info/PKG-INFO
# writing dependency_links to ISR.egg-info/dependency_links.txt
# writing requirements to ISR.egg-info/requires.txt
# writing top-level names to ISR.egg-info/top_level.txt
# writing manifest file 'ISR.egg-info/SOURCES.txt'
# reading manifest file 'ISR.egg-info/SOURCES.txt'
# writing manifest file 'ISR.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# ...
#
# creating build
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying ISR.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying ISR.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying ISR.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying ISR.egg-info/requires.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# ...

# %% [markdown]
# ## To enhance the images, the image can be put in data/input/sample and the source to be changed in the below cell. Already we have placed a sample image generated by BachGAN

# %%
import numpy as np
from PIL import Image

img = Image.open('/content/image-super-resolution/data/input/sample/result0001.jpeg')
lr_img = np.array(img)

# %%
from ISR.models import RDN

rdn = RDN(weights='psnr-small')
sr_img = rdn.predict(lr_img)
Image.fromarray(sr_img)
# Out:
# ...
# 10698752/10694096 [==============================] - 1s 0us/step
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F95A5DAF278>
